# %% [markdown]
# ### IMPORT LIBRARIES

# %%
# Import necessary liraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### LOAD THE DATASET

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\nidhi\Desktop\Intership\insurance.csv")

# %%
# Read the top rows of dataset
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# Check for null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# There is no null values/missing values present in the dataset.

# %%
#shape of dataset
df.shape
# Out:
# (1338, 7)

# %%
# Check the columns names
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %% [markdown]
# ### DATA CLEANING AND DATA EXPLORATION

# %%
# Summarize the statistical insights present in data set
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# **EXPENSES**:
# * total counts as 1338. max value as 63770.43 and min value as 1121.87
# * 25%th, 50%th and 75%th values are below the follow the points 4740.28, 9382.03, 16639.91
# * std value as 12110.011 where the value is higher then the mean value is far away from the max value

# %%
# outliers and check for expenses
fig = plt.figure(figsize=(7,7))
plt.boxplot(df['expenses'])
plt.title('Boxplot for Expenses', color='Navy', fontsize=16)
plt.show()

# %%
# Net sales that are equal to 0
df['expenses'].plot.hist()
plt.show()

# %% [markdown]
# **AGE**:
# * The total of 1338 rows present in this with maximum value of 64 and minimum value is 18.
# * average value of age column is 39 and followed by 25%th percentile values are less than 27, 50%th percentile values are less than 39, 75%th percentile of values are 51.
# * Std is 14.04 as it's bit large value we can conclude that the mean/avg value 39.20 is far away from the max value 64, anything but the age columns is having more distribution/variation

# %%
# Plot box graph to know its distribution

# df['age'].value_counts().plot(kind='box')
# fig = plt.figure(figsize=(7,7))
fig = plt.figure(figsize=(7,7))
plt.boxplot(df['age'])
plt.title('Boxplot for age', color='Navy', fontsize=16)
plt.show()

# %%
df['age'].value_counts().sum()
# Out:
# 1338

# %% [markdown]
# **Distribution of age**
# * min value of 18 and max value of 64
# * we can see outliers present
# * Total of 1338(which is equal to dataset size) unique values are present

# %%
fig = plt.figure(figsize=(7,7))
df['bmi'].value_counts().plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **BMI**:
# * Body Mass Index is a ratio of weight and height
# * Insurance companies use BMI to determine what your premium amount should be. The reason behind this is pretty straightforward. If they anticipate that your medical spending is bound to be more, it makes a direct impact on your premiums. Higher the expenditure, the higher will be your premium.
# * As per the WHO guidelines, these are the bands under which your body weight can be categorized:
# - BMI of 18.5 or lesser is categorized as underweight
# - BMI of 18.5- 24.9 is ideal and indicates a healthy body weight
# - BMI of 25-29.9 is considered overweight
# - BMI of 30 or more comes under the category of obese
# *  Since BMI signifies the health status of the individual's body, it affects the rate of life insurance premiums. A higher BMI means that the individual is at a higher risk of heart diseases and might frequently visit the hospitals due to weight-related issues.

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df['children'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **CHILDREN**:
# * total of 1338 data rows with max of 5 and min of 0.
# * low std means data are clustered around the mean, high std means data are more spread out.
# * 25%th percentile are below 0, 50%th values are below 1 and 75%th percentile are below 2
# * there are less variation in a dataset
# * 1,2,3,4,5 unique counts

# %%
df.describe(include=object)
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# **SEX**:
# * unique parameter as male and female, we can convert into binary values as 0 , 1
# * most repeated value as male
#
# **smoker**
# * unique parameter as yes and no, can be converted as 0 , 1
# * most repeated as no
#
# **REGION**
# * 4 different attributes present
# * southeast is the highest repeated attribute

# %%
#check coorelation
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.savefig('correlation.png', dpi=300, bbox_inches='tight')

# %%
sns.pairplot(df)

# %% [markdown]
# **CORRELATION**

# %% [markdown]
# There is no need of dropping any attributes, will continue with all seven.

# %% [markdown]
# ### COLLECTION OF QUESTIONS  - BIVARIATE ANALYSIS

# %% [markdown]
# **1. HOW ALL ATTRIBUTES ARE RELATED TO EXPENSES**

# %% [markdown]
# **2. HOW MANY ARE NON SMOKER AND SMOKER**

# %% [markdown]
# **3. DIFFERENCE OF MALE AND FEMALE EXPENSES**

# %% [markdown]
# **4. HOW REGION IS RELATED AND FROM WHERE THE MAXMIUM NUMBER PEOPLE ARE PRESENT**

# %% [markdown]
# **5. HOW BMI IS EFFECTING THE EXPENSES OR TARGET VARIABLE**

# %% [markdown]
# **6.IS CHILDREN IMPORTANT ATTRIBUTE TO CONSIDER**

# %% [markdown]
# ### MODEL SELECTION

# %%
reference:
Ordinary least square
